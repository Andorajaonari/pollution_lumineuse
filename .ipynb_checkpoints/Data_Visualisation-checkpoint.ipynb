# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
import matplotlib.ticker as ticker
import seaborn as sns
import datetime

# %%
df = pd.read_csv('../ID003.csv')

# %%
df['UTC_DATE'] = pd.to_datetime(df['UTC_DATE'], errors='coerce')
df['LOCTIME']= pd.to_datetime(df['LOCTIME'], errors='coerce')

# %%
df['LOC_DATE'] = df['UTC_DATE'] + pd.Timedelta(hours=4)

# %%
df = df.set_index('LOC_DATE') #Mettre l'index a l'heure de la Reunion

# %%
night = df[df['ALT_SUN']<= -18]
night.index = pd.to_datetime(night.index)

# %%
dates_de_nuit = night.index.date

# Compter le nombre de dates uniques
nombre_de_nuits = pd.Series(dates_de_nuit).nunique()

# Compter le nombre de dates uniques
nombre_de_nuits = pd.Series(dates_de_nuit).nunique()

print(f"Nombre total de nuits (jours avec au moins une observation nocturne) : {nombre_de_nuits}")

# print("\nDates des nuits identifiées :")
# print(pd.Series(dates_de_nuit).unique())
# Out:
# Nombre total de nuits (jours avec au moins une observation nocturne) : 780

# %%
night['dt'] = (night['T_AMB'] - night['T_SKY']).copy()
# Out:
# /tmp/ipykernel_12680/4280293771.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   night['dt'] = (night['T_AMB'] - night['T_SKY']).copy()

# %%
plt.figure(figsize=(10, 6))

plt.scatter(night['dt'], night['NSB'], marker='.', s=0.5, color ='red')

plt.suptitle('stars737(Observatoire Atmosphérique du Maïdo)')
plt.title(u'NSB vs ΔT')
plt.xlabel(u'ΔT (deg)')
plt.ylabel("NSB (mag/arcsec²)")
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
seuil_illumination = 0.05  # Pourcentage d'illumination max (5%)
seuil_altitude_lune = -10  # Altitude max de la lune (0 pour sous l'horizon)
seuil_betazen = 20
seuil_dt = 20

night_clear = night[
    (night['ILLUMOON'] < seuil_illumination) &
    (night['ALT_MOON'] < seuil_altitude_lune) &
#    (np.abs(night['BETAZEN']) > seuil_betazen) &
    (night['dt'] > seuil_dt)
].copy()
night_clear.index = pd.to_datetime(night_clear.index)

# %%
dates_de_nuit = night_clear.index.date

# Compter le nombre de dates uniques
nombre_de_nuits = pd.Series(dates_de_nuit).nunique()

# Compter le nombre de dates uniques
nombre_de_nuits = pd.Series(dates_de_nuit).nunique()

print(f"Nombre total de nuits claire (jours avec au moins une observation nocturne) : {nombre_de_nuits}")

print("\nDates des nuits identifiées :")
print(pd.Series(dates_de_nuit).unique())
# Out:
# Nombre total de nuits claire (jours avec au moins une observation nocturne) : 93
#
# Dates des nuits identifiées :
# [datetime.date(2022, 5, 30) datetime.date(2022, 5, 31)
#  datetime.date(2022, 6, 1) datetime.date(2022, 6, 26)
#  datetime.date(2022, 6, 27) datetime.date(2022, 6, 28)
#  datetime.date(2022, 6, 29) datetime.date(2022, 6, 30)
#  datetime.date(2022, 7, 1) datetime.date(2022, 7, 26)
#  datetime.date(2022, 7, 27) datetime.date(2022, 7, 28)
#  datetime.date(2022, 7, 29) datetime.date(2022, 7, 30)
#  datetime.date(2022, 7, 31) datetime.date(2022, 8, 25)
#  datetime.date(2022, 8, 26) datetime.date(2022, 8, 27)
#  datetime.date(2022, 8, 28) datetime.date(2022, 8, 29)
#  datetime.date(2022, 9, 24) datetime.date(2022, 9, 25)
#  datetime.date(2022, 9, 26) datetime.date(2022, 9, 27)
#  datetime.date(2022, 9, 28) datetime.date(2023, 2, 18)
#  datetime.date(2023, 2, 19) datetime.date(2023, 2, 20)
#  datetime.date(2023, 2, 22) datetime.date(2023, 3, 20)
# ...

# %%
dt = night_clear['T_AMB'] - night_clear['T_SKY']

# %%
plt.figure(figsize=(10, 6))

plt.scatter(dt, night_clear['NSB'], marker='.', s=0.5, color ='red')

plt.suptitle('stars737(Observatoire Atmosphérique du Maïdo)')
plt.title(u'NSB vs ΔT')
plt.xlabel(u'ΔT (deg)')
plt.ylabel("NSB (mag/arcsec²)")
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
min_nsb_date = night_clear['NSB'].idxmin()
min_nsb = night_clear['NSB'].min()
print(f"La valeur minimal de la brillance nocturne du ciel est égale à : {min_nsb} et date du {min_nsb_date}")
# Out:
# La valeur minimal de la brillance nocturne du ciel est égale à : 20.131132 et date du 2024-09-03 23:44:13

# %%
# Enlever les observations du lundi et mardi avant 20h
# Lundi est 0, Mardi est 1
is_monday_or_tuesday = night_clear.index.dayofweek.isin([0, 1])

is_between_18h_and_20h = (night_clear.index.hour >= 18) & (night_clear.index.hour < 21)

condition_to_exclude = is_monday_or_tuesday & is_between_18h_and_20h

night_clear_filtered_time = night_clear[~condition_to_exclude].copy()

# %%
dt_f = night_clear_filtered_time['T_AMB'] - night_clear_filtered_time['T_SKY']

# %%
plt.figure(figsize=(10, 6))

plt.scatter(dt_f, night_clear_filtered_time['NSB'], marker='.', s=0.5, color ='red')

plt.suptitle('stars737(Observatoire Atmosphérique du Maïdo)')
plt.title(u'NSB vs ΔT')
plt.xlabel(u'ΔT (deg)')
plt.ylabel("NSB (mag/arcsec²)")
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
min_nsb_date = night_clear_filtered_time['NSB'].idxmin()
min_nsb = night_clear_filtered_time['NSB'].min()
print(f"La valeur minimal de la brillance nocturne du ciel est égale à : {min_nsb} et date du {min_nsb_date}")
# Out:
# La valeur minimal de la brillance nocturne du ciel est égale à : 20.131132 et date du 2024-09-03 23:44:13

# %%
night_clear_filtered_time['NSB'].mean()
# Out:
# 21.10400423106153

# %%
#date = '2022-06'
start = '2024-09-01 17:00'
end ='2024-11-30 06:00'
#period = night_clear.loc[date] #selection de la periode a visualiser
#period = night_clear.loc[start:end].copy()
period = night_clear_filtered_time.loc[start:end].copy()

# %%
period['night'] = (period.index - pd.Timedelta(hours=6)).date #Creation d'une colonne night de 18h - 6h
period['night_time'] = ((period.index - pd.to_datetime(period['night'])) / pd.Timedelta(hours=1)) - 18 #Creation de la colonne nuit
#Visualisation de l'evolution du NSB par nuit dans un seul graph

fig, axes = plt.subplots(2, 1, figsize=(14, 10))

for d, g in period.groupby('night'):
    axes[0].errorbar(g['night_time'], g['NSB'], yerr = 0.06, markersize=1 ,elinewidth=0.3, fmt='.', label=d)
    axes[1].scatter(g['night_time'], g['T_AMB']-g['T_SKY'], marker='.', s=5, label=d)
    
plt.suptitle('stars737(Observatoire Atmosphérique du Maïdo)')

axes[0].set_title(f"NSB per Night {start} to {end}")
#axes[0].set_xlabel("Hours 18:00 to 6")
axes[0].set_ylabel("NSB (mag/arcsec²)")
axes[0].legend(fontsize='x-small', ncol=3)

axes[1].set_title("Temperature")
axes[1].set_ylabel("$T_{amb} - T_{sky}$ (deg)")
axes[1].legend(fontsize='x-small', ncol=3)

# Format x-axis to show HH:MM
def format_hour(x, _):
    hour = int(x + 18) % 24  # shift back to real time
    minute = int((x % 1) * 60)
    return f"{hour:02d}:{minute:02d}"

plt.gca().xaxis.set_major_locator(ticker.MultipleLocator(1))  # tick every 2 hours
plt.gca().xaxis.set_major_formatter(ticker.FuncFormatter(format_hour))

plt.tight_layout()
plt.show()

# %%
#night_clear['mois'] = night_clear.index.month
#night_clear['annee'] = night_clear.index.year
#night_clear['annee_mois'] = night_clear.index.to_period('M').astype(str)

# %%
night_clear_filtered_time['mois'] = night_clear_filtered_time.index.month
night_clear_filtered_time['annee'] = night_clear_filtered_time.index.year
night_clear_filtered_time['annee_mois'] = night_clear_filtered_time.index.to_period('M').astype(str)

# %%
plt.figure(figsize=(10, 6))

sns.boxplot(x='annee_mois', y='NSB', data=night_clear_filtered_time, hue='annee', palette='viridis', legend=False)

plt.suptitle('stars737(Observatoire Atmosphérique du Maïdo)')

plt.title('Évolution mensuelle de la Brillance du Ciel Nocturne (NSB) sur 3 Ans')
plt.xlabel('Mois et année', fontsize=12)
plt.ylabel('NSB (mag/arcsec²)', fontsize=12)

plt.xticks(rotation=90, ha='right', fontsize=10)

plt.grid(axis='y', linestyle='--', alpha=0.7)

plt.tight_layout()

plt.show()

# %%
#Exclure la date 2024-09-03
dates_a_exclure = ['2024-09-01',
                   '2024-09-02',
                   '2024-09-03',
                   '2024-09-04',
                   '2024-09-28',
                   '2024-09-29'
                 ]# Format 'AAAA-MM-JJ'

dates_a_exclure_dt = [pd.to_datetime(d).date() for d in dates_a_exclure]

# Convertir la date à exclure en objet Timestamp pour une comparaison précise
#date_ts = pd.to_datetime(date_a_exclure)
#mask_exclude_date = (night_clear_filtered_time.index.date != date_ts.date()) # Créer un masque qui est True pour toutes les dates SAUF celle à exclure
mask_keep_dates = ~pd.Series(night_clear_filtered_time.index.date, index=night_clear_filtered_time.index).isin(dates_a_exclure_dt)

#night_clear_filtered_date = night_clear_filtered_time[mask_exclude_date].copy()
night_clear_filtered_date  = night_clear_filtered_time[mask_keep_dates].copy()

# %%
dt_d = night_clear_filtered_date['T_AMB'] - night_clear_filtered_date['T_SKY']

# %%
plt.figure(figsize=(10, 6))

plt.scatter(dt_d, night_clear_filtered_date['NSB'], marker='.', s=0.5, color ='red')

plt.suptitle('stars737(Observatoire Atmosphérique du Maïdo)')
plt.title(u'NSB vs ΔT')
plt.xlabel(u'ΔT (deg)')
plt.ylabel("NSB (mag/arcsec²)")
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
night_clear_filtered_date['mois'] = night_clear_filtered_date.index.month
night_clear_filtered_date['annee'] = night_clear_filtered_date.index.year
night_clear_filtered_date['annee_mois'] = night_clear_filtered_date.index.to_period('M').astype(str)

# %%
plt.figure(figsize=(10, 6))

sns.boxplot(x='annee_mois', y='NSB', data=night_clear_filtered_date, hue='annee', palette='viridis', legend=False)

plt.suptitle('stars737(Observatoire Atmosphérique du Maïdo)')

plt.title('Évolution mensuelle de la Brillance du Ciel Nocturne (NSB) sur 3 Ans')
plt.xlabel('Mois et année', fontsize=12)
plt.ylabel('NSB (mag/arcsec²)', fontsize=12)

plt.xticks(rotation=90, ha='right', fontsize=10)

plt.grid(axis='y', linestyle='--', alpha=0.7)

plt.tight_layout()

plt.show()

# %%
night_filtered = night_clear_filtered_time

night_filtered['night'] = (night_filtered.index - pd.Timedelta(hours=6)).date #Creation d'une colonne night de 18h - 6h

mask_time_window = (
    (night_filtered.index.hour == 23) & (night_filtered.index.minute == 45) | # Condition pour 23:45
    (night_filtered.index.hour == 0)  & (night_filtered.index.minute == 0)  | # Condition pour 00:00
    (night_filtered.index.hour == 0)  & (night_filtered.index.minute == 15)   # Condition pour 00:15
)

nsb_midnight_window = night_filtered[mask_time_window].copy()

mean_nsb_at_midnight_window = nsb_midnight_window.groupby('night')['NSB'].mean()

# Renomme la série résultante pour plus de clarté
mean_nsb_at_midnight_window.name = 'mean_nsb_23h45_00h15_window'

# Convertie l'index 'night' de la Series résultante en DatetimeIndex pour faciliter le traçage
mean_nsb_at_midnight_window.index = pd.to_datetime(mean_nsb_at_midnight_window.index)

# %%
# Trace l'évolution de cette moyenne par nuit
photometer_error = 0.06 # mag/arcsec^2

plt.figure(figsize=(12, 6))

plt.errorbar(
    x=mean_nsb_at_midnight_window.index, 
    y=mean_nsb_at_midnight_window.values, 
    yerr=photometer_error,
    fmt='o',
    label=f'NSB Moyen (23:45 - 00:15) avec erreur $\\pm {photometer_error:.3f}$'
)

plt.suptitle('stars737(Observatoire Atmosphérique du Maïdo)')

plt.title('Évolution du NSB Moyen entre 23:45 et 00:15 par Nuit')
plt.xlabel('Date de la Nuit')
plt.ylabel('NSB Moyen (mag/arcsec²)')
plt.grid(True, linestyle='--', alpha=0.7)
plt.legend()
plt.tight_layout()
plt.show()
